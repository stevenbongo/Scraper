# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup ,re

# %%
html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html)

# %%
# \. : escape for "."         ../img/gifts/img.number.jpg

# %%
images = bsObj.findAll("img", {"src":re.compile("\.\.\/img\/gifts/img.*\.jpg")})

# %%
for image in images: 
    print(image["src"])
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %%
# Crawling

# %%
html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html)
for link in bsObj.findAll("a"):
    if "href" in link.attrs:
        print(link.attrs)
# Out:
# {'href': '/wiki/Wikipedia:Protection_policy#semi', 'title': 'This article is semi-protected to promote compliance with the policy on biographies of living persons'}
# {'class': ['mw-jump-link'], 'href': '#mw-head'}
# {'class': ['mw-jump-link'], 'href': '#searchInput'}
# {'href': '/wiki/Kevin_Bacon_(disambiguation)', 'class': ['mw-disambig'], 'title': 'Kevin Bacon (disambiguation)'}
# {'href': '/wiki/File:Kevin_Bacon_SDCC_2014.jpg', 'class': ['image']}
# {'href': '/wiki/Philadelphia,_Pennsylvania', 'class': ['mw-redirect'], 'title': 'Philadelphia, Pennsylvania'}
# {'href': '/wiki/Kyra_Sedgwick', 'title': 'Kyra Sedgwick'}
# {'href': '/wiki/Sosie_Bacon', 'title': 'Sosie Bacon'}
# {'href': '#cite_note-1'}
# {'href': '/wiki/Edmund_Bacon_(architect)', 'title': 'Edmund Bacon (architect)'}
# {'href': '/wiki/Michael_Bacon_(musician)', 'title': 'Michael Bacon (musician)'}
# {'href': '/wiki/Holly_Near', 'title': 'Holly Near'}
# ...

# %%
# ^ : at the beginning , ?! : doesn't contain , . : single chracter

# %%
for link in bsObj.find("div", {"id":"bodyContent"}).findAll("a",href=re.compile("^(/wiki/)((?!:).)*$")):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/I_Love_Dick_(TV_series)
# ...

# %%
# Create a Function

# %%
# load libraries

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re 
import datetime
import random

# %%
print(datetime.datetime.now())
# Out:
# 2021-01-11 14:57:58.821260

# %%
# random generator seed setting

# %%
random.seed(datetime.datetime.now())

# %%
def GetLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org" + articleUrl)
    bsObj = BeautifulSoup(html)
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href = re.compile("^(/wiki/)((?!:).)*$"))

# %%
links = GetLinks("/wiki/Kevin_Bacon")
links
# Out:
# [<a class="mw-disambig" href="/wiki/Kevin_Bacon_(disambiguation)" title="Kevin Bacon (disambiguation)">Kevin Bacon (disambiguation)</a>,
#  <a class="mw-redirect" href="/wiki/Philadelphia,_Pennsylvania" title="Philadelphia, Pennsylvania">Philadelphia, Pennsylvania</a>,
#  <a href="/wiki/Kyra_Sedgwick" title="Kyra Sedgwick">Kyra Sedgwick</a>,
#  <a href="/wiki/Sosie_Bacon" title="Sosie Bacon">Sosie Bacon</a>,
#  <a href="/wiki/Edmund_Bacon_(architect)" title="Edmund Bacon (architect)">Edmund Bacon</a>,
#  <a href="/wiki/Michael_Bacon_(musician)" title="Michael Bacon (musician)">Michael Bacon</a>,
#  <a href="/wiki/Holly_Near" title="Holly Near">Holly Near</a>,
#  <a href="/wiki/Footloose_(1984_film)" title="Footloose (1984 film)">Footloose</a>,
#  <a href="/wiki/JFK_(film)" title="JFK (film)">JFK</a>,
#  <a href="/wiki/A_Few_Good_Men" title="A Few Good Men">A Few Good Men</a>,
#  <a href="/wiki/Apollo_13_(film)" title="Apollo 13 (film)">Apollo 13</a>,
# ...

# %%
# random.randint(0,the number of links - 1) : pick an integer between 0 ~ the number of links - 1 randomly

# %%
random.seed(datetime.datetime.now()) 
def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl) 
    bsObj = BeautifulSoup(html) 
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$")) 

links = getLinks("/wiki/Kevin_Bacon") 
while len(links) > 0: 
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# original link[3] : <a href="/wiki/Geomatics" title="Geomatics">Geomatics</a>
# /wiki/Geomatics
# <a href="/wiki/Geoinformatics" title="Geoinformatics">Geoinformatics</a>
# <a href="/wiki/Geodesy" title="Geodesy">Geodesy</a>
# <a href="/wiki/Geodesy" title="Geodesy">Geodesy</a>
# <a href="/wiki/Geodynamics" title="Geodynamics">Geodynamics</a>
# <a href="/wiki/History_of_geodesy" title="History of geodesy">History</a>
# <a href="/wiki/Geographical_distance" title="Geographical distance">Geographical distance</a>
# <a href="/wiki/Geoid" title="Geoid">Geoid</a>
# <a href="/wiki/Figure_of_the_Earth" title="Figure of the Earth">Figure of the Earth</a>
# <a href="/wiki/Earth_radius" title="Earth radius">Earth radius</a>
# <a href="/wiki/Earth%27s_circumference" title="Earth's circumference">Earth's circumference</a>
# <a href="/wiki/Geodetic_datum" title="Geodetic datum">Geodetic datum</a>
# <a href="/wiki/Geodesic" title="Geodesic">Geodesic</a>
# ...
